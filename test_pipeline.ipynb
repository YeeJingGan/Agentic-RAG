# %%
import agent

agent.all_time_state['query'] = "Who is Wednesday Addams?"

# Agent 1: Query Rewriting Agent
reason = agent.query_rewrite_run()
print("Query Rewriting Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:10:14] INFO     Loading faiss with AVX2 support.                                                  ]8;id=379907;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\faiss\loader.py\loader.py]8;;\:]8;id=873708;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\faiss\loader.py#132\132]8;;\
#            INFO     Successfully loaded faiss with AVX2 support.                                      ]8;id=485414;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\faiss\loader.py\loader.py]8;;\:]8;id=457909;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\faiss\loader.py#134\134]8;;\
# [06:10:15] INFO     HTTP Request: POST                                                              ]8;id=134823;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=567220;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
# ...

# %%
# Agent 2: Knowledge Update Agent
reason = agent.knowledge_base_update_run()
print("Knowledge Update Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
#            INFO     DOC STORE GET_ALL_ARTICLES: ['President of the United States', 'Malaysia',     ]8;id=1123;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py\doc_store.py]8;;\:]8;id=877396;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py#137\137]8;;\
#                     'Joe Biden', 'Eleven (Stranger Things)', 'Will Byers', 'Euclidean distance',
#                     'Taxicab geometry', 'Stranger Things', 'List of sovereign states', 'Green
#                     tea', 'Lemon', 'Pitaya', 'Pineapple', 'Wednesday'] articles
# [06:10:18] INFO     HTTP Request: POST                                                              ]8;id=345845;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=630939;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
# ...

# %%
# Agent 3: Multiple Document Retrieval Agent
reason = agent.multiple_retrieval_run()
print("Multiple Document Retrieval Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
#            INFO     HTTP Request: POST                                                              ]8;id=320820;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=76435;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:ba
#                     tchEmbedContents "HTTP/1.1 200 OK"
#            INFO     RETRIEVER: Children- 10, Parents- 5, Articles- 1                                ]8;id=762088;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py\retriever.py]8;;\:]8;id=553548;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py#66\66]8;;\
# ...

# %%
# Generate Final Answer
response = agent.generator_run()
print("Final Answer Response:")
for res in response:
    print(res)
# Out:
# Final Answer Response:
#            INFO     AFC is enabled with max remote calls: 10.                                        ]8;id=969502;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py\models.py]8;;\:]8;id=713054;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py#5207\5207]8;;\
# [06:10:27] INFO     HTTP Request: POST                                                              ]8;id=882753;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=707021;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# ...

# %%
# Test Continuation with a different query

agent.all_time_state['query'] = "How about Eleven Byers?"

# Agent 1: Query Rewriting Agent
reason = agent.query_rewrite_run()
print("Query Rewriting Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:10:28] INFO     HTTP Request: POST                                                              ]8;id=9020;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=895483;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# [06:10:29] INFO     HTTP Request: POST                                                              ]8;id=147386;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=839646;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# ...

# %%
# Agent 2: Knowledge Update Agent
reason = agent.knowledge_base_update_run()
print("Knowledge Update Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:11:45] INFO     DOC STORE GET_ALL_ARTICLES: ['President of the United States', 'Malaysia',     ]8;id=241843;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py\doc_store.py]8;;\:]8;id=645308;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py#137\137]8;;\
#                     'Joe Biden', 'Eleven (Stranger Things)', 'Will Byers', 'Euclidean distance',
#                     'Taxicab geometry', 'Stranger Things', 'List of sovereign states', 'Green
#                     tea', 'Lemon', 'Pitaya', 'Pineapple', 'Wednesday', 'Wednesday Addams']
#                     articles
# [06:11:46] INFO     HTTP Request: POST                                                              ]8;id=333026;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=815425;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
# ...

# %%
# Agent 3: Multiple Document Retrieval Agent
reason = agent.multiple_retrieval_run()
print("Multiple Document Retrieval Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:12:27] INFO     HTTP Request: POST                                                              ]8;id=307626;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=133646;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:ba
#                     tchEmbedContents "HTTP/1.1 200 OK"
#            INFO     RETRIEVER: Children- 10, Parents- 8, Articles- 2                                ]8;id=218226;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py\retriever.py]8;;\:]8;id=879247;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py#66\66]8;;\
# ...

# %%
# Generate Final Answer
response = agent.generator_run()
print("Final Answer Response:")
for res in response:
    print(res)
# Out:
# Final Answer Response:
# [06:12:50] INFO     AFC is enabled with max remote calls: 10.                                        ]8;id=538509;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py\models.py]8;;\:]8;id=253994;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py#5207\5207]8;;\
# [06:12:54] INFO     HTTP Request: POST                                                              ]8;id=725073;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=595087;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# ...

# %%
# Test mix topic query
agent.all_time_state['query'] = "Are they having any relationship?"

# Agent 1: Query Rewriting Agent
reason = agent.query_rewrite_run()
print("Query Rewriting Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:14:15] INFO     HTTP Request: POST                                                              ]8;id=27069;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=374406;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# Query Rewriting Agent Reasoning: The user is asking a vague question "Are they having any relationship?". To optimize this query for Wikipedia, I need to know who "they" refers to. Without specific entities, I cannot provide a meaningful search query. Therefore, I need to ask the user for clarification.
# ...

# %%
# Agent 2: Knowledge Update Agent
reason = agent.knowledge_base_update_run()
print("Knowledge Update Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:14:51] INFO     DOC STORE GET_ALL_ARTICLES: ['President of the United States', 'Malaysia',     ]8;id=648249;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py\doc_store.py]8;;\:]8;id=302750;file://c:\Users\hp\Downloads\agentic_rag\storage\doc_store.py#137\137]8;;\
#                     'Joe Biden', 'Eleven (Stranger Things)', 'Will Byers', 'Euclidean distance',
#                     'Taxicab geometry', 'Stranger Things', 'List of sovereign states', 'Green
#                     tea', 'Lemon', 'Pitaya', 'Pineapple', 'Wednesday', 'Wednesday Addams']
#                     articles
# [06:14:52] INFO     HTTP Request: POST                                                              ]8;id=739169;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=986708;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
# ...

# %%
# Agent 3: Multiple Document Retrieval Agent
reason = agent.multiple_retrieval_run()
print("Multiple Document Retrieval Agent Reasoning:", reason)
print(agent.all_time_state)
# Out:
# [06:15:46] INFO     HTTP Request: POST                                                              ]8;id=748821;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=543674;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:ba
#                     tchEmbedContents "HTTP/1.1 200 OK"
#            INFO     RETRIEVER: Children- 10, Parents- 8, Articles- 2                                ]8;id=515860;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py\retriever.py]8;;\:]8;id=226340;file://c:\Users\hp\Downloads\agentic_rag\rag\retriever.py#66\66]8;;\
# ...

# %%
# Generate Final Answer
response = agent.generator_run()
print("Final Answer Response:")
for res in response:
    print(res)
# Out:
# Final Answer Response:
# [06:16:23] INFO     AFC is enabled with max remote calls: 10.                                        ]8;id=314027;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py\models.py]8;;\:]8;id=798995;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\google\genai\models.py#5207\5207]8;;\
# [06:16:25] INFO     HTTP Request: POST                                                              ]8;id=674463;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=25170;file://c:\Users\hp\Downloads\agentic_rag\.venv\Lib\site-packages\httpx\_client.py#1025\1025]8;;\
#                     https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:g
#                     enerateContent "HTTP/1.1 200 OK"
# ...
